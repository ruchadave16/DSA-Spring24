# %%
import matplotlib.pyplot as plt

Y = [[1.570965, 14.630249, 11.279366, 31.391223, 64.664868, 112.950736, 200.450681],
     [0.65701, 8.239173, 1.785757, 17.565889, 27.482296, 52.065261, 89.461043],
     [0.522411, 1.143174, 0.611659, 1.151497, 0.684173, 0.87114, 1.171461],
     [1.100267, 15.672881, 6.115357, 28.709404, 133.394448, 253.994441, 422.032048]]
X = [100, 500, 1000, 2500, 5000, 7500, 10000]
plt.scatter(X, Y[2])
plt.scatter(X, Y[1])
plt.scatter(X, Y[0])
plt.scatter(X, Y[3])
plt.plot(X, Y[2], '')
plt.plot(X, Y[1], '')
plt.plot(X, Y[0], 'g')
plt.plot(X, Y[3], 'r')
plt.legend(["Merge Sort", "Selection Sort", "Insert Sort", "Bubble Sort"])
plt.xlabel("Total List Size")
plt.ylabel("Time in Milliseconds (ms)")
plt.title("Benchmarking Sorting Algorithms")
plt.savefig('BenchmarkingAlgorithms.png')
